# %%
import os
import torch
import trimesh
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.metrics import confusion_matrix

import seaborn as sns
import matplotlib.pyplot as plt

from tqdm import tqdm as tqdm

# %%
def angle_between_vectors(v1, v2):
    return np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))


def extract_single_edge_features(mesh, edge_idx):
    edge = mesh.edges[edge_idx]
    adjacent_faces = mesh.face_adjacency_edges[edge_idx]

    # Compute dihedral angle
    dihedral_angle = mesh.face_adjacency_angles[edge_idx]  # Dihedral angle between the two adjacent faces

    # Compute inner angles (opposite angles in the two adjacent faces)
    inner_angles = []
    for face_idx in adjacent_faces:
        face = mesh.faces[face_idx]
        opposite_vertex = [v for v in face if v not in edge][0]
        opposite_angle = angle_between_vectors(mesh.vertices[opposite_vertex] - mesh.vertices[edge[0]],
                                               mesh.vertices[opposite_vertex] - mesh.vertices[edge[1]])
        inner_angles.append(opposite_angle)

    # Compute edge/height ratios for the two adjacent faces
    edge_lengths = mesh.edges_unique_length[edge_idx]  # Edge length
    heights = []
    for face_idx in adjacent_faces:
        face = mesh.faces[face_idx]
        opposite_vertex = [v for v in face if v not in edge][0]
        height = np.linalg.norm(np.cross(mesh.vertices[opposite_vertex] - mesh.vertices[edge[0]],
                                         mesh.vertices[opposite_vertex] - mesh.vertices[edge[1]])) / edge_lengths
        heights.append(height)

    # Collect the feature vector
    edge_feature = [dihedral_angle, inner_angles[0], inner_angles[1], edge_lengths / heights[0], edge_lengths / heights[1]]
    return edge_feature, edge[0], edge[1]

def extract_edge_features(mesh):
    edges = mesh.edges

    num_edges = len(edges)
    edge_features = []

    processed_edges = set()
    edge_idx = 0

    for edge_idx in range(num_edges):
        edge = edges[edge_idx]
        print(edge)
        v1 = edge[0]
        v2 = edge[1]
                
        print(f'Edge {edge_idx}: {v1} -> {v2}')
                
        adjacent_faces = mesh.face_adjacency_edges[v1]
        print(f'Adjacent faces v1: {mesh.face_adjacency_edges[v1]}')
        print(f'Adjacent faces v2: {mesh.face_adjacency_edges[v2]}')

        # Compute dihedral angle
        dihedral_angle = mesh.face_adjacency_angles[edge_idx]  # Dihedral angle between the two adjacent faces

        # Compute inner angles (opposite angles in the two adjacent faces)
        inner_angles = []
        for face_idx in adjacent_faces:
            face = mesh.faces[face_idx]
            opposite_vertex = [v for v in face if v not in edge][0]
            opposite_angle = angle_between_vectors(mesh.vertices[opposite_vertex] - mesh.vertices[edge[0]],
                                                mesh.vertices[opposite_vertex] - mesh.vertices[edge[1]])
            inner_angles.append(opposite_angle)

        # Compute edge/height ratios for the two adjacent faces
        edge_lengths = mesh.edges_unique_length[edge_idx]  # Edge length
        heights = []
        for face_idx in adjacent_faces:
            face = mesh.faces[face_idx]
            opposite_vertex = [v for v in face if v not in edge][0]
            height = np.linalg.norm(np.cross(mesh.vertices[opposite_vertex] - mesh.vertices[edge[0]],
                                            mesh.vertices[opposite_vertex] - mesh.vertices[edge[1]])) / edge_lengths
            heights.append(height)

        # Collect the feature vector
        edge_feature = [dihedral_angle, inner_angles[0], inner_angles[1], edge_lengths / heights[0], edge_lengths / heights[1]]
                
                
        edge_features.append(edge_feature)
        edge_idx += 1

    return np.array(edge_features)
  
  
def create_image_like_tensor(mesh):
    edge_features = extract_edge_features(mesh)
    num_edges = len(edge_features)
    num_features = len(edge_features[0])

    image_tensor = torch.zeros((1, num_edges, num_features))

    for edge_idx in range(num_edges):
        image_tensor[0, edge_idx, :] = torch.tensor(edge_features[edge_idx])

    return image_tensor


def save_image_tensor(image_tensor, output_path):
    torch.save(image_tensor, output_path)

def process_mesh_dataset(dataset_path, output_dir):
    """
    Process the mesh dataset and save the image-like tensors in the specified folder.

    Args:
        dataset_path (str): Path to the folder containing mesh .obj files.
        output_dir (str): Folder where the tensors will be saved.
    """
    for root, dirs, files in os.walk(dataset_path):
        for file in files:
            if file.endswith(".obj"):
                mesh_path = os.path.join(root, file)
                print(f"Processing {mesh_path} ... ")
               
                mesh = trimesh.load(mesh_path)
                image_tensor = create_image_like_tensor(mesh)

                # Create output path
                relative_path = os.path.relpath(mesh_path, dataset_path)
                tensor_output_path = os.path.join(output_dir, relative_path.replace('.obj', '.pt'))
                os.makedirs(os.path.dirname(tensor_output_path), exist_ok=True)

                save_image_tensor(image_tensor, tensor_output_path)
                print(f"Saved tensor for {file} at {tensor_output_path}")

# Example usage
dataset_path = "datasets/human/bouncing"  # Replace with your dataset folder containing .obj files
output_dir = "mesh_images"  # Folder where image-like tensors will be saved

process_mesh_dataset(dataset_path, output_dir)
# Out:
# Processing datasets/human/bouncing/mesh_0170.obj ...
# [   8 9892]
# Edge 0: 8 -> 9892
# Adjacent faces v1: [ 6 20]
# Adjacent faces v2: [3409 3420]
# [9892 9876]
# Edge 1: 9892 -> 9876
# Adjacent faces v1: [3409 3420]
# Adjacent faces v2: [3325 3415]
# [9876    8]
# Edge 2: 9876 -> 8
# Adjacent faces v1: [3325 3415]
# Adjacent faces v2: [ 6 20]
# [9876 9874]
# Edge 3: 9876 -> 9874
# Adjacent faces v1: [3325 3415]
# Adjacent faces v2: [3385 3414]
# [9874    8]
# Edge 4: 9874 -> 8
# Adjacent faces v1: [3385 3414]
# Adjacent faces v2: [ 6 20]
# [   8 9876]
# Edge 5: 8 -> 9876
# Adjacent faces v1: [ 6 20]
# Adjacent faces v2: [3325 3415]
# [9863   88]
# Edge 6: 9863 -> 88
# Adjacent faces v1: [3298 3411]
# Adjacent faces v2: [75 76]
# [88 87]
# Edge 7: 88 -> 87
# Adjacent faces v1: [75 76]
# Adjacent faces v2: [25 76]
# [  87 9863]
# Edge 8: 87 -> 9863
# Adjacent faces v1: [25 76]
# Adjacent faces v2: [3298 3411]
# [  88 9866]
# Edge 9: 88 -> 9866
# Adjacent faces v1: [75 76]
# Adjacent faces v2: [3320 3412]
# [9866    9]
# Edge 10: 9866 -> 9
# Adjacent faces v1: [3320 3412]
# Adjacent faces v2: [ 7 20]
# [ 9 88]
# Edge 11: 9 -> 88
# Adjacent faces v1: [ 7 20]
# Adjacent faces v2: [75 76]
# [30  1]
# Edge 12: 30 -> 1
# Adjacent faces v1: [ 3 44]
# Adjacent faces v2: [12 13]
# [ 1 31]
# Edge 13: 1 -> 31
# Adjacent faces v1: [12 13]
# Adjacent faces v2: [37 44]
# [31 30]
# Edge 14: 31 -> 30
# Adjacent faces v1: [37 44]
# Adjacent faces v2: [ 3 44]
# [57 31]
# Edge 15: 57 -> 31
# Adjacent faces v1: [59 60]
# Adjacent faces v2: [37 44]
# [31  1]
# Edge 16: 31 -> 1
# Adjacent faces v1: [37 44]
# Adjacent faces v2: [12 13]
# [ 1 57]
# Edge 17: 1 -> 57
# Adjacent faces v1: [12 13]
# Adjacent faces v2: [59 60]
# [ 1 17]
# Edge 18: 1 -> 17
# Adjacent faces v1: [12 13]
# Adjacent faces v2: [ 1 31]
# [17 57]
# Edge 19: 17 -> 57
# Adjacent faces v1: [ 1 31]
# Adjacent faces v2: [59 60]
# [57  1]
# Edge 20: 57 -> 1
# Adjacent faces v1: [59 60]
# Adjacent faces v2: [12 13]
# [17  2]
# Edge 21: 17 -> 2
# Adjacent faces v1: [ 1 31]
# Adjacent faces v2: [13 14]
# [ 2 18]
# Edge 22: 2 -> 18
# Adjacent faces v1: [13 14]
# Adjacent faces v2: [30 31]
# [18 17]
# Edge 23: 18 -> 17
# Adjacent faces v1: [30 31]
# Adjacent faces v2: [ 1 31]
# [58 18]
# Edge 24: 58 -> 18
# Adjacent faces v1: [ 7 61]
# Adjacent faces v2: [30 31]
# [18  2]
# Edge 25: 18 -> 2
# Adjacent faces v1: [30 31]
# Adjacent faces v2: [13 14]
# [ 2 58]
# Edge 26: 2 -> 58
# Adjacent faces v1: [13 14]
# Adjacent faces v2: [ 7 61]
# [   2 9816]
# Edge 27: 2 -> 9816
# Adjacent faces v1: [13 14]
# Adjacent faces v2: [3327 3396]
# [9816   58]
# Edge 28: 9816 -> 58
# Adjacent faces v1: [3327 3396]
# Adjacent faces v2: [ 7 61]
# [58  2]
# Edge 29: 58 -> 2
# Adjacent faces v1: [ 7 61]
# Adjacent faces v2: [13 14]
# [64 58]
# Edge 30: 64 -> 58
# Adjacent faces v1: [32 64]
# Adjacent faces v2: [ 7 61]
# [  58 9816]
# Edge 31: 58 -> 9816
# Adjacent faces v1: [ 7 61]
# Adjacent faces v2: [3327 3396]
# [9816   64]
# Edge 32: 9816 -> 64
# Adjacent faces v1: [3327 3396]
# Adjacent faces v2: [32 64]
# [9816 9809]
# Edge 33: 9816 -> 9809
# Adjacent faces v1: [3327 3396]
# Adjacent faces v2: [3346 3394]
# [9809   64]
# Edge 34: 9809 -> 64
# Adjacent faces v1: [3346 3394]
# Adjacent faces v2: [32 64]
# [  64 9816]
# Edge 35: 64 -> 9816
# Adjacent faces v1: [32 64]
# Adjacent faces v2: [3327 3396]
# [9823 9836]
# Edge 36: 9823 -> 9836
# Adjacent faces v1: [3314 3399]
# Adjacent faces v2: [3289 3402]
# [9836   65]
# Edge 37: 9836 -> 65
# Adjacent faces v1: [3289 3402]
# Adjacent faces v2: [58 64]
# [  65 9823]
# Edge 38: 65 -> 9823
# Adjacent faces v1: [58 64]
# Adjacent faces v2: [3314 3399]
# [19 65]
# Edge 39: 19 -> 65
# Adjacent faces v1: [33 34]
# Adjacent faces v2: [58 64]
# [  65 9836]
# Edge 40: 65 -> 9836
# Adjacent faces v1: [58 64]
# Adjacent faces v2: [3289 3402]
# [9836   19]
# Edge 41: 9836 -> 19
# Adjacent faces v1: [3289 3402]
# Adjacent faces v2: [33 34]
# [9836 9807]
# Edge 42: 9836 -> 9807
# Adjacent faces v1: [3289 3402]
# Adjacent faces v2: [3309 3394]
# [9807   19]
# Edge 43: 9807 -> 19
# Adjacent faces v1: [3309 3394]
# Adjacent faces v2: [33 34]
# [  19 9836]
# Edge 44: 19 -> 9836
# Adjacent faces v1: [33 34]
# Adjacent faces v2: [3289 3402]
# [60 19]
# Edge 45: 60 -> 19
# Adjacent faces v1: [27 62]
# Adjacent faces v2: [33 34]
# [  19 9807]
# Edge 46: 19 -> 9807
# Adjacent faces v1: [33 34]
# Adjacent faces v2: [3309 3394]
# [9807   60]
# Edge 47: 9807 -> 60
# Adjacent faces v1: [3309 3394]
# Adjacent faces v2: [27 62]
# [9805   33]
# Edge 48: 9805 -> 33
# Adjacent faces v1: [3346 3393]
# Adjacent faces v2: [40 45]
# [33 60]
# Edge 49: 33 -> 60
# Adjacent faces v1: [40 45]
# Adjacent faces v2: [27 62]
# [  60 9805]
# Edge 50: 60 -> 9805
# Adjacent faces v1: [27 62]
# Adjacent faces v2: [3346 3393]
# [9805 9824]
# Edge 51: 9805 -> 9824
# Adjacent faces v1: [3346 3393]
# Adjacent faces v2: [3322 3399]
# [9824   34]
# Edge 52: 9824 -> 34
# Adjacent faces v1: [3322 3399]
# Adjacent faces v2: [16 46]
# [  34 9805]
# Edge 53: 34 -> 9805
# Adjacent faces v1: [16 46]
# Adjacent faces v2: [3346 3393]
# [  34 9813]
# Edge 54: 34 -> 9813
# Adjacent faces v1: [16 46]
# Adjacent faces v2: [3376 3395]
# [9813  106]
# Edge 55: 9813 -> 106
# Adjacent faces v1: [3376 3395]
# Adjacent faces v2: [79 84]
# [106  34]
# Edge 56: 106 -> 34
# Adjacent faces v1: [79 84]
# Adjacent faces v2: [16 46]
# [ 53 106]
# Edge 57: 53 -> 106
# Adjacent faces v1: [19 59]
# Adjacent faces v2: [79 84]
# [ 106 9813]
# Edge 58: 106 -> 9813
# Adjacent faces v1: [79 84]
# Adjacent faces v2: [3376 3395]
# [9813   53]
# Edge 59: 9813 -> 53
# Adjacent faces v1: [3376 3395]
# Adjacent faces v2: [19 59]
# [9811   53]
# Edge 60: 9811 -> 53
# Adjacent faces v1: [3320 3395]
# Adjacent faces v2: [19 59]
# [  53 9813]
# Edge 61: 53 -> 9813
# Adjacent faces v1: [19 59]
# Adjacent faces v2: [3376 3395]
# [9813 9811]
# Edge 62: 9813 -> 9811
# Adjacent faces v1: [3376 3395]
# Adjacent faces v2: [3320 3395]
# [115  10]
# Edge 63: 115 -> 10
# Adjacent faces v1: [51 89]
# Adjacent faces v2: [24 25]
# [  10 9903]
# Edge 64: 10 -> 9903
# Adjacent faces v1: [24 25]
# Adjacent faces v2: [3382 3423]
# [9903  115]
# Edge 65: 9903 -> 115
# Adjacent faces v1: [3382 3423]
# Adjacent faces v2: [51 89]
# [ 11 115]
# Edge 66: 11 -> 115
# Adjacent faces v1: [22 26]
# Adjacent faces v2: [51 89]
# [ 115 9903]
# Edge 67: 115 -> 9903
# Adjacent faces v1: [51 89]
# Adjacent faces v2: [3382 3423]
# [9903   11]
# Edge 68: 9903 -> 11
# Adjacent faces v1: [3382 3423]
# Adjacent faces v2: [22 26]
# [  11 9885]
# Edge 69: 11 -> 9885
# Adjacent faces v1: [22 26]
# Adjacent faces v2: [3297 3418]
# [9885   37]
# Edge 70: 9885 -> 37
# Adjacent faces v1: [3297 3418]
# Adjacent faces v2: [47 48]
# [37 11]
# Edge 71: 37 -> 11
# Adjacent faces v1: [47 48]
# Adjacent faces v2: [22 26]
# [9885    3]
# Edge 72: 9885 -> 3
# Adjacent faces v1: [3297 3418]
# Adjacent faces v2: [ 4 15]
# [ 3 37]
# Edge 73: 3 -> 37
# Adjacent faces v1: [ 4 15]
# Adjacent faces v2: [47 48]
# [  37 9885]
# Edge 74: 37 -> 9885
# Adjacent faces v1: [47 48]
# Adjacent faces v2: [3297 3418]
# [38  3]
# Edge 75: 38 -> 3
# Adjacent faces v1: [ 0 49]
# Adjacent faces v2: [ 4 15]
# [   3 9872]
# Edge 76: 3 -> 9872
# Adjacent faces v1: [ 4 15]
# Adjacent faces v2: [3332 3414]
# [9872   38]
# Edge 77: 9872 -> 38
# Adjacent faces v1: [3332 3414]
# Adjacent faces v2: [ 0 49]
# [12 38]
# Edge 78: 12 -> 38
# Adjacent faces v1: [23 26]
# Adjacent faces v2: [ 0 49]
# [  38 9872]
# Edge 79: 38 -> 9872
# Adjacent faces v1: [ 0 49]
# Adjacent faces v2: [3332 3414]
# [9872   12]
# Edge 80: 9872 -> 12
# Adjacent faces v1: [3332 3414]
# Adjacent faces v2: [23 26]
# [14 13]
# Edge 81: 14 -> 13
# Adjacent faces v1: [26 27]
# Adjacent faces v2: [23 27]
# [  13 9894]
# Edge 82: 13 -> 9894
# Adjacent faces v1: [23 27]
# Adjacent faces v2: [3251 3421]
# [9894   14]
# Edge 83: 9894 -> 14
# Adjacent faces v1: [3251 3421]
# Adjacent faces v2: [26 27]
# [9894 9897]
# Edge 84: 9894 -> 9897
# Adjacent faces v1: [3251 3421]
# Adjacent faces v2: [3313 3422]
# [9897   14]
# Edge 85: 9897 -> 14
# Adjacent faces v1: [3313 3422]
# Adjacent faces v2: [26 27]
# [  14 9894]
# Edge 86: 14 -> 9894
# Adjacent faces v1: [26 27]
# Adjacent faces v2: [3251 3421]
# [39 14]
# Edge 87: 39 -> 14
# Adjacent faces v1: [ 8 49]
# Adjacent faces v2: [26 27]
# [  14 9897]
# Edge 88: 14 -> 9897
# Adjacent faces v1: [26 27]
# Adjacent faces v2: [3313 3422]
# [9897   39]
# Edge 89: 9897 -> 39
# Adjacent faces v1: [3313 3422]
# Adjacent faces v2: [ 8 49]
# [9888 9902]
# Edge 90: 9888 -> 9902
# Adjacent faces v1: [3268 3419]
# Adjacent faces v2: [3314 3423]
# [9902   41]
# Edge 91: 9902 -> 41
# Adjacent faces v1: [3314 3423]
# Adjacent faces v2: [35 50]
# [  41 9888]
# Edge 92: 41 -> 9888
# Adjacent faces v1: [35 50]
# Adjacent faces v2: [3268 3419]
# [9902    4]
# Edge 93: 9902 -> 4
# Adjacent faces v1: [3314 3423]
# Adjacent faces v2: [ 1 17]
# [ 4 41]
# Edge 94: 4 -> 41
# Adjacent faces v1: [ 1 17]
# Adjacent faces v2: [35 50]
# [  41 9902]
# Edge 95: 41 -> 9902
# Adjacent faces v1: [35 50]
# Adjacent faces v2: [3314 3423]
# [15 41]
# Edge 96: 15 -> 41
# Adjacent faces v1: [24 28]
# Adjacent faces v2: [35 50]
# [41  4]
# Edge 97: 41 -> 4
# Adjacent faces v1: [35 50]
# Adjacent faces v2: [ 1 17]
# [ 4 15]
# Edge 98: 4 -> 15
# Adjacent faces v1: [ 1 17]
# Adjacent faces v2: [24 28]
# [55 67]
# Edge 99: 55 -> 67
# Adjacent faces v1: [19 60]
# Adjacent faces v2: [19 66]
# [  67 9804]
# Edge 100: 67 -> 9804
# Adjacent faces v1: [19 66]
# Adjacent faces v2: [3344 3392]
# [9804   55]
# Edge 101: 9804 -> 55
# Adjacent faces v1: [3344 3392]
# Adjacent faces v2: [19 60]
# [9804    5]
# Edge 102: 9804 -> 5
# Adjacent faces v1: [3344 3392]
# Adjacent faces v2: [ 2 17]
# [ 5 55]
# Edge 103: 5 -> 55
# Adjacent faces v1: [ 2 17]
# Adjacent faces v2: [19 60]
# [  55 9804]
# Edge 104: 55 -> 9804
# Adjacent faces v1: [19 60]
# Adjacent faces v2: [3344 3392]
# [   6 9841]
# Edge 105: 6 -> 9841
# Adjacent faces v1: [ 2 18]
# Adjacent faces v2: [3369 3403]
# [9841   20]
# Edge 106: 9841 -> 20
# Adjacent faces v1: [3369 3403]
# Adjacent faces v2: [35 36]
# [20  6]
# Edge 107: 20 -> 6
# Adjacent faces v1: [35 36]
# Adjacent faces v2: [ 2 18]
# [9841    7]
# Edge 108: 9841 -> 7
# Adjacent faces v1: [3369 3403]
# Adjacent faces v2: [17 18]
# [ 7 20]
# Edge 109: 7 -> 20
# Adjacent faces v1: [17 18]
# Adjacent faces v2: [35 36]
# [  20 9841]
# Edge 110: 20 -> 9841
# Adjacent faces v1: [35 36]
# Adjacent faces v2: [3369 3403]
# [9832    7]
# Edge 111: 9832 -> 7
# Adjacent faces v1: [3299 3401]
# Adjacent faces v2: [17 18]
# [   7 9819]
# Edge 112: 7 -> 9819
# Adjacent faces v1: [17 18]
# Adjacent faces v2: [3279 3397]
# [9819 9832]
# Edge 113: 9819 -> 9832
# Adjacent faces v1: [3279 3397]
# Adjacent faces v2: [3299 3401]
# [26 22]
# Edge 114: 26 -> 22
# Adjacent faces v1: [39 40]
# Adjacent faces v2: [11 37]
# [  22 9834]
# Edge 115: 22 -> 9834
# Adjacent faces v1: [11 37]
# Adjacent faces v2: [3363 3401]
# [9834   26]
# Edge 116: 9834 -> 26
# Adjacent faces v1: [3363 3401]
# Adjacent faces v2: [39 40]
# [9834   23]
# Edge 117: 9834 -> 23
# Adjacent faces v1: [3363 3401]
# Adjacent faces v2: [ 3 38]
# [23 26]
# Edge 118: 23 -> 26
# Adjacent faces v1: [ 3 38]
# Adjacent faces v2: [39 40]
# [  26 9834]
# Edge 119: 26 -> 9834
# Adjacent faces v1: [39 40]
# Adjacent faces v2: [3363 3401]
# [27 26]
# Edge 120: 27 -> 26
# Adjacent faces v1: [ 4 41]
# Adjacent faces v2: [39 40]
# [26 23]
# Edge 121: 26 -> 23
# Adjacent faces v1: [39 40]
# Adjacent faces v2: [ 3 38]
# [23 27]
# Edge 122: 23 -> 27
# Adjacent faces v1: [ 3 38]
# Adjacent faces v2: [ 4 41]
# [9892    8]
# Edge 123: 9892 -> 8
# Adjacent faces v1: [3409 3420]
# Adjacent faces v2: [ 6 20]
# [ 8 71]
# Edge 124: 8 -> 71
# Adjacent faces v1: [ 6 20]
# Adjacent faces v2: [12 68]
# [  71 9892]
# Edge 125: 71 -> 9892
# Adjacent faces v1: [12 68]
# Adjacent faces v2: [3409 3420]
# [49  8]
# Edge 126: 49 -> 8
# Adjacent faces v1: [17 57]
# Adjacent faces v2: [ 6 20]
# [   8 9874]
# Edge 127: 8 -> 9874
# Adjacent faces v1: [ 6 20]
# Adjacent faces v2: [3385 3414]
# [9874   49]
# Edge 128: 9874 -> 49
# Adjacent faces v1: [3385 3414]
# Adjacent faces v2: [17 57]
# [9861 9891]
# Edge 129: 9861 -> 9891
# Adjacent faces v1: [3375 3410]
# Adjacent faces v2: [3409 3419]
# [9891   50]
# Edge 130: 9891 -> 50
# Adjacent faces v1: [3409 3419]
# Adjacent faces v2: [31 57]
# [  50 9861]
# Edge 131: 50 -> 9861
# Adjacent faces v1: [31 57]
# Adjacent faces v2: [3375 3410]
# [35 50]
# Edge 132: 35 -> 50
# Adjacent faces v1: [16 47]
# Adjacent faces v2: [31 57]
# [  50 9891]
# Edge 133: 50 -> 9891
# Adjacent faces v1: [31 57]
# Adjacent faces v2: [3409 3419]
# [9891   35]
# Edge 134: 9891 -> 35
# Adjacent faces v1: [3409 3419]
# Adjacent faces v2: [16 47]
# [9881 9863]
# Edge 135: 9881 -> 9863
# Adjacent faces v1: [3296 3417]
# Adjacent faces v2: [3298 3411]
# [9863   36]
# Edge 136: 9863 -> 36
# Adjacent faces v1: [3298 3411]
# Adjacent faces v2: [42 48]
# [  36 9881]
# Edge 137: 36 -> 9881
# Adjacent faces v1: [42 48]
# Adjacent faces v2: [3296 3417]
# [87 36]
# Edge 138: 87 -> 36
# Adjacent faces v1: [25 76]
# Adjacent faces v2: [42 48]
# [  36 9863]
# Edge 139: 36 -> 9863
# Adjacent faces v1: [42 48]
# Adjacent faces v2: [3298 3411]
# [9863   87]
# Edge 140: 9863 -> 87
# Adjacent faces v1: [3298 3411]
# Adjacent faces v2: [25 76]
# [88  9]
# Edge 141: 88 -> 9
# Adjacent faces v1: [75 76]
# Adjacent faces v2: [ 7 20]
# [  9 134]
# Edge 142: 9 -> 134
# Adjacent faces v1: [ 7 20]
# Adjacent faces v2: [69 97]
# [134  88]
# Edge 143: 134 -> 88
# Adjacent faces v1: [69 97]
# Adjacent faces v2: [75 76]
# [51  9]
# Edge 144: 51 -> 9
# Adjacent faces v1: [ 2 58]
# Adjacent faces v2: [ 7 20]
# [   9 9910]
# Edge 145: 9 -> 9910
# Adjacent faces v1: [ 7 20]
# Adjacent faces v2: [3273 3426]
# [9910   51]
# Edge 146: 9910 -> 51
# Adjacent faces v1: [3273 3426]
# Adjacent faces v2: [ 2 58]
# [52 51]
# Edge 147: 52 -> 51
# Adjacent faces v1: [18 58]
# Adjacent faces v2: [ 2 58]
# [  51 9910]
# Edge 148: 51 -> 9910
# Adjacent faces v1: [ 2 58]
# Adjacent faces v2: [3273 3426]
# [9910   52]
# Edge 149: 9910 -> 52
# Adjacent faces v1: [3273 3426]
# Adjacent faces v2: [18 58]
# [44 37]
# Edge 150: 44 -> 37
# Adjacent faces v1: [51 52]
# Adjacent faces v2: [47 48]
# [37  3]
# Edge 151: 37 -> 3
# Adjacent faces v1: [47 48]
# Adjacent faces v2: [ 4 15]
# [ 3 44]
# Edge 152: 3 -> 44
# Adjacent faces v1: [ 4 15]
# Adjacent faces v2: [51 52]
# [ 3 38]
# Edge 153: 3 -> 38
# Adjacent faces v1: [ 4 15]
# Adjacent faces v2: [ 0 49]
# [38 44]
# Edge 154: 38 -> 44
# Adjacent faces v1: [ 0 49]
# Adjacent faces v2: [51 52]
# [44  3]
# Edge 155: 44 -> 3
# Adjacent faces v1: [51 52]
# Adjacent faces v2: [ 4 15]
# [68 12]
# Edge 156: 68 -> 12
# Adjacent faces v1: [59 66]
# Adjacent faces v2: [23 26]
# [12 13]
# Edge 157: 12 -> 13
# Adjacent faces v1: [23 26]
# Adjacent faces v2: [23 27]
# [13 68]
# Edge 158: 13 -> 68
# Adjacent faces v1: [23 27]
# Adjacent faces v2: [59 66]
# [13 14]
# Edge 159: 13 -> 14
# Adjacent faces v1: [23 27]
# Adjacent faces v2: [26 27]
# [14 68]
# Edge 160: 14 -> 68
# Adjacent faces v1: [26 27]
# Adjacent faces v2: [59 66]
# [68 13]
# Edge 161: 68 -> 13
# Adjacent faces v1: [59 66]
# Adjacent faces v2: [23 27]
# [130  45]
# Edge 162: 130 -> 45
# Adjacent faces v1: [79 95]
# Adjacent faces v2: [53 54]
# [  45 9888]
# Edge 163: 45 -> 9888
# Adjacent faces v1: [53 54]
# Adjacent faces v2: [3268 3419]
# [9888  130]
# Edge 164: 9888 -> 130
# Adjacent faces v1: [3268 3419]
# Adjacent faces v2: [79 95]
# [ 41 130]
# Edge 165: 41 -> 130
# Adjacent faces v1: [35 50]
# Adjacent faces v2: [79 95]
# [ 130 9888]
# Edge 166: 130 -> 9888
# Adjacent faces v1: [79 95]
# Adjacent faces v2: [3268 3419]
# [9888   41]
# Edge 167: 9888 -> 41
# Adjacent faces v1: [3268 3419]
# Adjacent faces v2: [35 50]
# [9887   69]
# Edge 168: 9887 -> 69
# Adjacent faces v1: [3417 3418]
# Adjacent faces v2: [54 67]
# [69 15]
# Edge 169: 69 -> 15
# Adjacent faces v1: [54 67]
# Adjacent faces v2: [24 28]
# [  15 9887]
# Edge 170: 15 -> 9887
# Adjacent faces v1: [24 28]
# Adjacent faces v2: [3417 3418]
# [9887   16]
# Edge 171: 9887 -> 16
# Adjacent faces v1: [3417 3418]
# Adjacent faces v2: [ 1 30]
# [16 46]
# Edge 172: 16 -> 46
# Adjacent faces v1: [ 1 30]
# Adjacent faces v2: [ 5 55]
# [  46 9887]
# Edge 173: 46 -> 9887
# Adjacent faces v1: [ 5 55]
# Adjacent faces v2: [3417 3418]
# [58 64]
# Edge 174: 58 -> 64
# Adjacent faces v1: [ 7 61]
# Adjacent faces v2: [32 64]
# [64 78]
# Edge 175: 64 -> 78
# Adjacent faces v1: [32 64]
# Adjacent faces v2: [70 71]
# [78 58]
# Edge 176: 78 -> 58
# Adjacent faces v1: [70 71]
# Adjacent faces v2: [ 7 61]
# [65 93]
# Edge 177: 65 -> 93
# Adjacent faces v1: [58 64]
# Adjacent faces v2: [64 78]
# [  93 9823]
# Edge 178: 93 -> 9823
# Adjacent faces v1: [64 78]
# Adjacent faces v2: [3314 3399]
# [9823   65]
# Edge 179: 9823 -> 65
# Adjacent faces v1: [3314 3399]
# Adjacent faces v2: [58 64]
# [9805   34]
# Edge 180: 9805 -> 34
# Adjacent faces v1: [3346 3393]
# Adjacent faces v2: [16 46]
# [34 33]
# Edge 181: 34 -> 33
# Adjacent faces v1: [16 46]
# Adjacent faces v2: [40 45]
# [  33 9805]
# Edge 182: 33 -> 9805
# Adjacent faces v1: [40 45]
# Adjacent faces v2: [3346 3393]
# [54 53]
# Edge 183: 54 -> 53
# Adjacent faces v1: [33 59]
# Adjacent faces v2: [19 59]
# [  53 9811]
# Edge 184: 53 -> 9811
# Adjacent faces v1: [19 59]
# Adjacent faces v2: [3320 3395]
# [9811   54]
# Edge 185: 9811 -> 54
# Adjacent faces v1: [3320 3395]
# Adjacent faces v2: [33 59]
# [55 94]
# Edge 186: 55 -> 94
# Adjacent faces v1: [19 60]
# Adjacent faces v2: [14 79]
# [94 67]
# Edge 187: 94 -> 67
# Adjacent faces v1: [14 79]
# Adjacent faces v2: [19 66]
# [67 55]
# Edge 188: 67 -> 55
# Adjacent faces v1: [19 66]
# Adjacent faces v2: [19 60]
# [61 81]
# Edge 189: 61 -> 81
# Adjacent faces v1: [28 62]
# Adjacent faces v2: [22 73]
# [81  7]
# Edge 190: 81 -> 7
# Adjacent faces v1: [22 73]
# Adjacent faces v2: [17 18]
# [ 7 61]
# Edge 191: 7 -> 61
# Adjacent faces v1: [17 18]
# Adjacent faces v2: [28 62]
# [   7 9832]
# Edge 192: 7 -> 9832
# Adjacent faces v1: [17 18]
# Adjacent faces v2: [3299 3401]
# [9832   61]
# Edge 193: 9832 -> 61
# Adjacent faces v1: [3299 3401]
# Adjacent faces v2: [28 62]
# [61  7]
# Edge 194: 61 -> 7
# Adjacent faces v1: [28 62]
# Adjacent faces v2: [17 18]
# [  91 9820]
# Edge 195: 91 -> 9820
# Adjacent faces v1: [56 77]
# Adjacent faces v2: [3349 3397]
# [9820   21]
# Edge 196: 9820 -> 21
# Adjacent faces v1: [3349 3397]
# Adjacent faces v2: [ 3 37]
# [21 91]
# Edge 197: 21 -> 91
# Adjacent faces v1: [ 3 37]
# Adjacent faces v2: [56 77]
# [  21 9800]
# Edge 198: 21 -> 9800
# Adjacent faces v1: [ 3 37]
# Adjacent faces v2: [3357 3391]
# [9800   91]
# Edge 199: 9800 -> 91
# Adjacent faces v1: [3357 3391]
# Adjacent faces v2: [56 77]
# [91 21]
# Edge 200: 91 -> 21
# Adjacent faces v1: [56 77]
# Adjacent faces v2: [ 3 37]
# [73 91]
# Edge 201: 73 -> 91
# Adjacent faces v1: [14 68]
# Adjacent faces v2: [56 77]
# [  91 9800]
# Edge 202: 91 -> 9800
# Adjacent faces v1: [56 77]
# Adjacent faces v2: [3357 3391]
# [9800   73]
# Edge 203: 9800 -> 73
# Adjacent faces v1: [3357 3391]
# Adjacent faces v2: [14 68]
# [9800   22]
# Edge 204: 9800 -> 22
# Adjacent faces v1: [3357 3391]
# Adjacent faces v2: [11 37]
# [22 73]
# Edge 205: 22 -> 73
# Adjacent faces v1: [11 37]
# Adjacent faces v2: [14 68]
# [  73 9800]
# Edge 206: 73 -> 9800
# Adjacent faces v1: [14 68]
# Adjacent faces v2: [3357 3391]
# [26 73]
# Edge 207: 26 -> 73
# Adjacent faces v1: [39 40]
# Adjacent faces v2: [14 68]
# [73 22]
# Edge 208: 73 -> 22
# Adjacent faces v1: [14 68]
# Adjacent faces v2: [11 37]
# [22 26]
# Edge 209: 22 -> 26
# Adjacent faces v1: [11 37]
# Adjacent faces v2: [39 40]
# [27 23]
# Edge 210: 27 -> 23
# Adjacent faces v1: [ 4 41]
# Adjacent faces v2: [ 3 38]
# [23 62]
# Edge 211: 23 -> 62
# Adjacent faces v1: [ 3 38]
# Adjacent faces v2: [17 63]
# [62 27]
# Edge 212: 62 -> 27
# Adjacent faces v1: [17 63]
# Adjacent faces v2: [ 4 41]
# [  23 9803]
# Edge 213: 23 -> 9803
# Adjacent faces v1: [ 3 38]
# Adjacent faces v2: [3278 3392]
# [9803   62]
# Edge 214: 9803 -> 62
# Adjacent faces v1: [3278 3392]
# Adjacent faces v2: [17 63]
# [62 23]
# Edge 215: 62 -> 23
# Adjacent faces v1: [17 63]
# Adjacent faces v2: [ 3 38]
# [28 62]
# Edge 216: 28 -> 62
# Adjacent faces v1: [15 41]
# Adjacent faces v2: [17 63]
# [  62 9803]
# Edge 217: 62 -> 9803
# Adjacent faces v1: [17 63]
# Adjacent faces v2: [3278 3392]
# [9803   28]
# Edge 218: 9803 -> 28
# Adjacent faces v1: [3278 3392]
# Adjacent faces v2: [15 41]
# [9803   24]
# Edge 219: 9803 -> 24
# Adjacent faces v1: [3278 3392]
# Adjacent faces v2: [12 38]
# [24 28]
# Edge 220: 24 -> 28
# Adjacent faces v1: [12 38]
# Adjacent faces v2: [15 41]
# [  28 9803]
# Edge 221: 28 -> 9803
# Adjacent faces v1: [15 41]
# Adjacent faces v2: [3278 3392]
# [24 25]
# Edge 222: 24 -> 25
# Adjacent faces v1: [12 38]
# Adjacent faces v2: [14 39]
# [25 75]
# Edge 223: 25 -> 75
# Adjacent faces v1: [14 39]
# Adjacent faces v2: [42 70]
# [75 24]
# Edge 224: 75 -> 24
# Adjacent faces v1: [42 70]
# Adjacent faces v2: [12 38]
# [76 75]
# Edge 225: 76 -> 75
# Adjacent faces v1: [ 8 71]
# Adjacent faces v2: [42 70]
# [75 25]
# Edge 226: 75 -> 25
# Adjacent faces v1: [42 70]
# Adjacent faces v2: [14 39]
# [25 76]
# Edge 227: 25 -> 76
# Adjacent faces v1: [14 39]
# Adjacent faces v2: [ 8 71]
# [  25 9802]
# Edge 228: 25 -> 9802
# Adjacent faces v1: [14 39]
# Adjacent faces v2: [3277 3392]
# [9802   76]
# Edge 229: 9802 -> 76
# Adjacent faces v1: [3277 3392]
# Adjacent faces v2: [ 8 71]
# [76 25]
# Edge 230: 76 -> 25
# Adjacent faces v1: [ 8 71]
# Adjacent faces v2: [14 39]
# [82 76]
# Edge 231: 82 -> 76
# Adjacent faces v1: [26 73]
# Adjacent faces v2: [ 8 71]
# [  76 9802]
# Edge 232: 76 -> 9802
# Adjacent faces v1: [ 8 71]
# Adjacent faces v2: [3277 3392]
# [9802   82]
# Edge 233: 9802 -> 82
# Adjacent faces v1: [3277 3392]
# Adjacent faces v2: [26 73]
# [9832 9820]
# Edge 234: 9832 -> 9820
# Adjacent faces v1: [3299 3401]
# Adjacent faces v2: [3349 3397]
# [9820   61]
# Edge 235: 9820 -> 61
# Adjacent faces v1: [3349 3397]
# Adjacent faces v2: [28 62]
# [  61 9832]
# Edge 236: 61 -> 9832
# Adjacent faces v1: [28 62]
# Adjacent faces v2: [3299 3401]
# [91 61]
# Edge 237: 91 -> 61
# Adjacent faces v1: [56 77]
# Adjacent faces v2: [28 62]
# [  61 9820]
# Edge 238: 61 -> 9820
# Adjacent faces v1: [28 62]
# Adjacent faces v2: [3349 3397]
# [9820   91]
# Edge 239: 9820 -> 91
# Adjacent faces v1: [3349 3397]
# Adjacent faces v2: [56 77]
# [26 27]
# Edge 240: 26 -> 27
# Adjacent faces v1: [39 40]
# Adjacent faces v2: [ 4 41]
# [ 27 118]
# Edge 241: 27 -> 118
# Adjacent faces v1: [ 4 41]
# Adjacent faces v2: [72 90]
# [118  26]
# Edge 242: 118 -> 26
# Adjacent faces v1: [72 90]
# Adjacent faces v2: [39 40]
# [  29 9812]
# Edge 243: 29 -> 9812
# Adjacent faces v1: [ 0 43]
# Adjacent faces v2: [3336 3395]
# [9812   56]
# Edge 244: 9812 -> 56
# Adjacent faces v1: [3336 3395]
# Adjacent faces v2: [33 60]
# [56 29]
# Edge 245: 56 -> 29
# Adjacent faces v1: [33 60]
# Adjacent faces v2: [ 0 43]
# [77 56]
# Edge 246: 77 -> 56
# Adjacent faces v1: [49 71]
# Adjacent faces v2: [33 60]
# [  56 9812]
# Edge 247: 56 -> 9812
# Adjacent faces v1: [33 60]
# Adjacent faces v2: [3336 3395]
# [9812   77]
# Edge 248: 9812 -> 77
# Adjacent faces v1: [3336 3395]
# Adjacent faces v2: [49 71]
# [9812   30]
# Edge 249: 9812 -> 30
# Adjacent faces v1: [3336 3395]
# Adjacent faces v2: [ 3 44]
# [30 77]
# Edge 250: 30 -> 77
# Adjacent faces v1: [ 3 44]
# Adjacent faces v2: [49 71]
# [  77 9812]
# Edge 251: 77 -> 9812
# Adjacent faces v1: [49 71]
# Adjacent faces v2: [3336 3395]
# [30 31]
# Edge 252: 30 -> 31
# Adjacent faces v1: [ 3 44]
# Adjacent faces v2: [37 44]
# [31 77]
# Edge 253: 31 -> 77
# Adjacent faces v1: [37 44]
# Adjacent faces v2: [49 71]
# [77 30]
# Edge 254: 77 -> 30
# Adjacent faces v1: [49 71]
# Adjacent faces v2: [ 3 44]
# [103  77]
# Edge 255: 103 -> 77
# Adjacent faces v1: [63 83]
# Adjacent faces v2: [49 71]
# [77 31]
# Edge 256: 77 -> 31
# Adjacent faces v1: [49 71]
# Adjacent faces v2: [37 44]
# [ 31 103]
# Edge 257: 31 -> 103
# Adjacent faces v1: [37 44]
# Adjacent faces v2: [63 83]
# [17 18]
# Edge 258: 17 -> 18
# Adjacent faces v1: [ 1 31]
# Adjacent faces v2: [30 31]
# [18 63]
# Edge 259: 18 -> 63
# Adjacent faces v1: [30 31]
# Adjacent faces v2: [18 63]
# [63 17]
# Edge 260: 63 -> 17
# Adjacent faces v1: [18 63]
# Adjacent faces v2: [ 1 31]
# [19 60]
# Edge 261: 19 -> 60
# Adjacent faces v1: [33 34]
# Adjacent faces v2: [27 62]
# [60 59]
# Edge 262: 60 -> 59
# Adjacent faces v1: [27 62]
# Adjacent faces v2: [23 62]
# [59 19]
# Edge 263: 59 -> 19
# Adjacent faces v1: [23 62]
# Adjacent faces v2: [33 34]
# [59 60]
# Edge 264: 59 -> 60
# Adjacent faces v1: [23 62]
# Adjacent faces v2: [27 62]
# [60 33]
# Edge 265: 60 -> 33
# Adjacent faces v1: [27 62]
# Adjacent faces v2: [40 45]
# [33 59]
# Edge 266: 33 -> 59
# Adjacent faces v1: [40 45]
# Adjacent faces v2: [23 62]
# [54 67]
# Edge 267: 54 -> 67
# Adjacent faces v1: [33 59]
# Adjacent faces v2: [19 66]
# [ 67 107]
# Edge 268: 67 -> 107
# Adjacent faces v1: [19 66]
# Adjacent faces v2: [49 85]
# [107  54]
# Edge 269: 107 -> 54
# Adjacent faces v1: [49 85]
# Adjacent faces v2: [33 59]
# [  35 9881]
# Edge 270: 35 -> 9881
# Adjacent faces v1: [16 47]
# Adjacent faces v2: [3296 3417]
# [9881   36]
# Edge 271: 9881 -> 36
# Adjacent faces v1: [3296 3417]
# Adjacent faces v2: [42 48]
# [36 35]
# Edge 272: 36 -> 35
# Adjacent faces v1: [42 48]
# Adjacent faces v2: [16 47]
# [87 86]
# Edge 273: 87 -> 86
# Adjacent faces v1: [25 76]
# Adjacent faces v2: [25 75]
# [86 36]
# Edge 274: 86 -> 36
# Adjacent faces v1: [25 75]
# Adjacent faces v2: [42 48]
# [36 87]
# Edge 275: 36 -> 87
# Adjacent faces v1: [42 48]
# Adjacent faces v2: [25 76]
# [51 89]
# Edge 276: 51 -> 89
# Adjacent faces v1: [ 2 58]
# Adjacent faces v2: [30 77]
# [89  9]
# Edge 277: 89 -> 9
# Adjacent faces v1: [30 77]
# Adjacent faces v2: [ 7 20]
# [ 9 51]
# Edge 278: 9 -> 51
# Adjacent faces v1: [ 7 20]
# Adjacent faces v2: [ 2 58]
# [ 10 113]
# Edge 279: 10 -> 113
# Adjacent faces v1: [24 25]
# Adjacent faces v2: [87 88]
# [113  52]
# Edge 280: 113 -> 52
# Adjacent faces v1: [87 88]
# Adjacent faces v2: [18 58]
# [52 10]
# Edge 281: 52 -> 10
# Adjacent faces v1: [18 58]
# Adjacent faces v2: [24 25]
# [11 37]
# Edge 282: 11 -> 37
# Adjacent faces v1: [22 26]
# Adjacent faces v2: [47 48]
# [ 37 109]
# Edge 283: 37 -> 109
# Adjacent faces v1: [47 48]
# Adjacent faces v2: [36 86]
# [109  11]
# Edge 284: 109 -> 11
# Adjacent faces v1: [36 86]
# Adjacent faces v2: [22 26]
# [ 44 141]
# Edge 285: 44 -> 141
# Adjacent faces v1: [51 52]
# Adjacent faces v2: [ 89 100]
# [141  37]
# Edge 286: 141 -> 37
# Adjacent faces v1: [ 89 100]
# Adjacent faces v2: [47 48]
# [37 44]
# Edge 287: 37 -> 44
# Adjacent faces v1: [47 48]
# Adjacent faces v2: [51 52]
# [68 14]
# Edge 288: 68 -> 14
# Adjacent faces v1: [59 66]
# Adjacent faces v2: [26 27]
# [14 79]
# Edge 289: 14 -> 79
# Adjacent faces v1: [26 27]
# Adjacent faces v2: [ 5 72]
# [79 68]
# Edge 290: 79 -> 68
# Adjacent faces v1: [ 5 72]
# Adjacent faces v2: [59 66]
# [39 79]
# Edge 291: 39 -> 79
# Adjacent faces v1: [ 8 49]
# Adjacent faces v2: [ 5 72]
# [79 14]
# Edge 292: 79 -> 14
# Adjacent faces v1: [ 5 72]
# Adjacent faces v2: [26 27]
# [14 39]
# Edge 293: 14 -> 39
# Adjacent faces v1: [26 27]
# Adjacent faces v2: [ 8 49]
# [41 15]
# Edge 294: 41 -> 15
# Adjacent faces v1: [35 50]
# Adjacent faces v2: [24 28]
# [15 80]
# Edge 295: 15 -> 80
# Adjacent faces v1: [24 28]
# Adjacent faces v2: [ 6 72]
# [80 41]
# Edge 296: 80 -> 41
# Adjacent faces v1: [ 6 72]
# Adjacent faces v2: [35 50]
# [  16 9905]
# Edge 297: 16 -> 9905
# Adjacent faces v1: [ 1 30]
# Adjacent faces v2: [3339 3424]
# [9905   47]
# Edge 298: 9905 -> 47
# Adjacent faces v1: [3339 3424]
# Adjacent faces v2: [29 56]
# [47 16]
# Edge 299: 47 -> 16
# Adjacent faces v1: [29 56]
# Adjacent faces v2: [ 1 30]
# [70 42]
# Edge 300: 70 -> 42
# Adjacent faces v1: [55 67]
# Adjacent faces v2: [ 9 51]
# [  42 9892]
# Edge 301: 42 -> 9892
# Adjacent faces v1: [ 9 51]
# Adjacent faces v2: [3409 3420]
# [9892   70]
# Edge 302: 9892 -> 70
# Adjacent faces v1: [3409 3420]
# Adjacent faces v2: [55 67]
# [49 71]
# Edge 303: 49 -> 71
# Adjacent faces v1: [17 57]
# Adjacent faces v2: [12 68]
# [71  8]
# Edge 304: 71 -> 8
# Adjacent faces v1: [12 68]
# Adjacent faces v2: [ 6 20]
# [ 8 49]
# Edge 305: 8 -> 49
# Adjacent faces v1: [ 6 20]
# Adjacent faces v2: [17 57]
# [49  0]
# Edge 306: 49 -> 0
# Adjacent faces v1: [17 57]
# Adjacent faces v2: [5 6]
# [   0 9880]
# Edge 307: 0 -> 9880
# Adjacent faces v1: [5 6]
# Adjacent faces v2: [3415 3416]
# [9880   49]
# Edge 308: 9880 -> 49
# Adjacent faces v1: [3415 3416]
# Adjacent faces v2: [17 57]
# [44 38]
# Edge 309: 44 -> 38
# Adjacent faces v1: [51 52]
# Adjacent faces v2: [ 0 49]
# [ 38 128]
# Edge 310: 38 -> 128
# Adjacent faces v1: [ 0 49]
# Adjacent faces v2: [67 94]
# [128  44]
# Edge 311: 128 -> 44
# Adjacent faces v1: [67 94]
# Adjacent faces v2: [51 52]
# [12 68]
# Edge 312: 12 -> 68
# Adjacent faces v1: [23 26]
# Adjacent faces v2: [59 66]
# [ 68 142]
# Edge 313: 68 -> 142
# Adjacent faces v1: [59 66]
# Adjacent faces v2: [  7 101]
# [142  12]
# Edge 314: 142 -> 12
# Adjacent faces v1: [  7 101]
# Adjacent faces v2: [23 26]
# [40 45]
# Edge 315: 40 -> 45
# Adjacent faces v1: [43 49]
# Adjacent faces v2: [53 54]
# [ 45 130]
# Edge 316: 45 -> 130
# Adjacent faces v1: [53 54]
# Adjacent faces v2: [79 95]
# [130  40]
# Edge 317: 130 -> 40
# Adjacent faces v1: [79 95]
# Adjacent faces v2: [43 49]
# [130  41]
# Edge 318: 130 -> 41
# Adjacent faces v1: [79 95]
# Adjacent faces v2: [35 50]
# [41 96]
# Edge 319: 41 -> 96
# Adjacent faces v1: [35 50]
# Adjacent faces v2: [68 79]
# [ 96 130]
# Edge 320: 96 -> 130
# Adjacent faces v1: [68 79]
# Adjacent faces v2: [79 95]
# [97 69]
# Edge 321: 97 -> 69
# Adjacent faces v1: [15 80]
# Adjacent faces v2: [54 67]
# [  69 9887]
# Edge 322: 69 -> 9887
# Adjacent faces v1: [54 67]
# Adjacent faces v2: [3417 3418]
# [9887   97]
# Edge 323: 9887 -> 97
# Adjacent faces v1: [3417 3418]
# Adjacent faces v2: [15 80]
# [9887   46]
# Edge 324: 9887 -> 46
# Adjacent faces v1: [3417 3418]
# Adjacent faces v2: [ 5 55]
# [46 97]
# Edge 325: 46 -> 97
# Adjacent faces v1: [ 5 55]
# Adjacent faces v2: [15 80]
# [  97 9887]
# Edge 326: 97 -> 9887
# Adjacent faces v1: [15 80]
# Adjacent faces v2: [3417 3418]
# [149  48]
# Edge 327: 149 -> 48
# Adjacent faces v1: [ 57 103]
# Adjacent faces v2: [ 1 57]
# [48 42]
# Edge 328: 48 -> 42
# Adjacent faces v1: [ 1 57]
# Adjacent faces v2: [ 9 51]
# [ 42 149]
# Edge 329: 42 -> 149
# Adjacent faces v1: [ 9 51]
# Adjacent faces v2: [ 57 103]
# [71 70]
# Edge 330: 71 -> 70
# Adjacent faces v1: [12 68]
# Adjacent faces v2: [55 67]
# [  70 9892]
# Edge 331: 70 -> 9892
# Adjacent faces v1: [55 67]
# Adjacent faces v2: [3409 3420]
# [9892   71]
# Edge 332: 9892 -> 71
# Adjacent faces v1: [3409 3420]
# Adjacent faces v2: [12 68]
# [132  85]
# Edge 333: 132 -> 85
# Adjacent faces v1: [80 96]
# Adjacent faces v2: [24 75]
# [85 49]
# Edge 334: 85 -> 49
# Adjacent faces v1: [24 75]
# Adjacent faces v2: [17 57]
# [ 49 132]
# Edge 335: 49 -> 132
# Adjacent faces v1: [17 57]
# Adjacent faces v2: [80 96]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 133
#     130 dataset_path = "datasets/human/bouncing"  # Replace with your dataset folder containing .obj files
#     131 output_dir = "mesh_images"  # Folder where image-like tensors will be saved
# --> 133 process_mesh_dataset(dataset_path, output_dir)
#
# Cell In[2], line 119, in process_mesh_dataset(dataset_path, output_dir)
#     116 print(f"Processing {mesh_path} ... ")
#     118 mesh = trimesh.load(mesh_path)
# --> 119 image_tensor = create_image_like_tensor(mesh)
#     121 # Create output path
#     122 relative_path = os.path.relpath(mesh_path, dataset_path)
#
# Cell In[2], line 89, in create_image_like_tensor(mesh)
#      88 def create_image_like_tensor(mesh):
# ---> 89     edge_features = extract_edge_features(mesh)
#      90     num_edges = len(edge_features)
#      91     num_features = len(edge_features[0])
#
# Cell In[2], line 69, in extract_edge_features(mesh)
#      66     inner_angles.append(opposite_angle)
#      68 # Compute edge/height ratios for the two adjacent faces
# ---> 69 edge_lengths = mesh.edges_unique_length[edge_idx]  # Edge length
#      70 heights = []
#      71 for face_idx in adjacent_faces:
#
# File ~/.local/lib/python3.10/site-packages/trimesh/caching.py:132, in cache_decorator.<locals>.get_cached(*args, **kwargs)
#     129 name = function.__name__
#     130 # do the dump logic ourselves to avoid
#     131 # verifying cache twice per call
# --> 132 self._cache.verify()
#     133 # access cache dict to avoid automatic validation
#     134 # since we already called cache.verify manually
#     135 if name in self._cache.cache:
#     136     # already stored so return value
#
# File ~/.local/lib/python3.10/site-packages/trimesh/caching.py:375, in Cache.verify(self)
#     372     return
#     374 # check the hash of our data
# --> 375 id_new = self._id_function()
#     377 # things changed
#     378 if id_new != self.id_current:
#
# File ~/.local/lib/python3.10/site-packages/trimesh/caching.py:692, in DataStore.__hash__(self)
#     680 """
#     681 Get a hash reflecting everything in the DataStore.
#     682
#    (...)
#     686   hash of data in hexadecimal
#     687 """
#     688 # only hash values that aren't None
#     689 # or if they are arrays require length greater than zero
#     690 return hash_fast(
#     691     np.array(
# --> 692         [
#     693             hash(v)
#     694             for v in self.data.values()
#     695             if v is not None and (not hasattr(v, "__len__") or len(v) > 0)
#     696         ],
#     697         dtype=np.int64,
#     698     ).tobytes()
#     699 )
#
# File ~/.local/lib/python3.10/site-packages/trimesh/caching.py:693, in <listcomp>(.0)
#     680 """
#     681 Get a hash reflecting everything in the DataStore.
#     682
#    (...)
#     686   hash of data in hexadecimal
#     687 """
#     688 # only hash values that aren't None
#     689 # or if they are arrays require length greater than zero
#     690 return hash_fast(
#     691     np.array(
#     692         [
# --> 693             hash(v)
#     694             for v in self.data.values()
#     695             if v is not None and (not hasattr(v, "__len__") or len(v) > 0)
#     696         ],
#     697         dtype=np.int64,
#     698     ).tobytes()
#     699 )
#
# File ~/.local/lib/python3.10/site-packages/trimesh/caching.py:222, in TrackedArray.__hash__(self)
#     219     return self._hashed
#     221 # run a hashing function on the C-order bytes copy
# --> 222 hashed = hash_fast(self.tobytes(order="C"))
#     224 # assign the value and set the flag
#     225 self._hashed = hashed
#
# File ~/.local/lib/python3.10/site-packages/trimesh/caching.py:49, in hash_fallback(item)
#      48 def hash_fallback(item):
# ---> 49     return int(_blake2b(item, usedforsecurity=False).hexdigest(), 16)
#
# KeyboardInterrupt:

# %%
def mesh_to_pointcloud(mesh, num_points=1024, normalize=True):
    """Convert a trimesh mesh object to a point cloud."""
    point_cloud = mesh.sample(num_points)  # Randomly sample points from mesh surface
    if normalize:
        point_cloud -= np.mean(point_cloud, axis=0)
        point_cloud /= np.max(np.linalg.norm(point_cloud, axis=1))
    return point_cloud.astype(np.float32)


class MeshDataset(Dataset):
    def __init__(self, root_dir, num_points=1024, transform=None):
        self.root_dir = root_dir
        self.num_points = num_points
        self.transform = transform
        self.samples = []

        for class_name in os.listdir(root_dir):
            class_dir = os.path.join(root_dir, class_name)
            if os.path.isdir(class_dir):
                obj_files = [f for f in os.listdir(class_dir) if f.endswith('.obj')]
                for obj_file in obj_files:
                    obj_path = os.path.join(class_dir, obj_file)
                    label = class_name 
                    self.samples.append((obj_path, label))

        self.class_to_idx = {cls_name: idx for idx, cls_name in enumerate(sorted(set([s[1] for s in self.samples])))}
        self.idx_to_class = {idx: cls_name for cls_name, idx in self.class_to_idx.items()}

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        obj_path, label = self.samples[idx]
        
        mesh = trimesh.load(obj_path)
        point_cloud = mesh_to_pointcloud(mesh, num_points=self.num_points, normalize=True)        
        
        label_idx = self.class_to_idx[label]

        if self.transform:
            point_cloud = self.transform(point_cloud)

        point_cloud_tensor = torch.tensor(point_cloud, dtype=torch.float32)
        label_tensor = torch.tensor(label_idx, dtype=torch.long)

        return point_cloud_tensor, label_tensor

root_dir = 'datasets/human'

dataset = MeshDataset(root_dir, num_points=1024)

dataset_size = len(dataset)
test_size = int(0.10 * dataset_size)
val_size = int(0.15 * dataset_size)
train_size = dataset_size - test_size - val_size

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size], generator=torch.Generator().manual_seed(42))

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)


print(f'Number of samples: {len(dataset)}')
print(f'Classes: {dataset.class_to_idx}')
print(f'Number of classes: {len(dataset.class_to_idx)}')
print(dataset.samples)
for i, count in enumerate(np.bincount([dataset.class_to_idx[s[1]] for s in dataset.samples])):
    print(f'Class {i} - {dataset.idx_to_class[i]}: {count} samples')

print('Train size:', len(train_dataset))
print('Validation size:', len(val_dataset))
print('Test size:', len(test_dataset))

# %%
class SimplePointNet(nn.Module):
    def __init__(self, num_classes, input_dim=3):
        """
        Args:
            num_classes (int): Number of output classes.
            input_dim (int): Dimension of the input point cloud (default is 3 for x, y, z).
        """
        super(SimplePointNet, self).__init__()

        # Input transformation MLP
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 128)
        self.fc3 = nn.Linear(128, 1024)

        # Batch normalization layers applied after the fully connected layers
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(1024)

        # Global feature vector aggregation
        self.maxpool = nn.MaxPool1d(1024)

        # Fully connected layers for classification
        self.fc4 = nn.Linear(1024, 512)
        self.fc5 = nn.Linear(512, 256)
        self.fc6 = nn.Linear(256, num_classes)

        # Batch normalization layers for the classification layers
        self.bn4 = nn.BatchNorm1d(512)
        self.bn5 = nn.BatchNorm1d(256)

    def forward(self, x):
        # x: (batch_size, num_points, 3)
        batch_size = x.size(0)
        num_points = x.size(1)

        # Apply the first MLP layers
        x = F.relu(self.fc1(x))  # (batch_size, num_points, 64)
        x = self.bn1(x.transpose(1, 2)).transpose(1, 2)  # (batch_size, num_points, 64)
        
        x = F.relu(self.fc2(x))  # (batch_size, num_points, 128)
        x = self.bn2(x.transpose(1, 2)).transpose(1, 2)  # (batch_size, num_points, 128)
        
        x = F.relu(self.fc3(x))  # (batch_size, num_points, 1024)
        x = self.bn3(x.transpose(1, 2)).transpose(1, 2)  # (batch_size, num_points, 1024)

        # Global feature vector aggregation (max-pooling over points)
        x = x.permute(0, 2, 1)  # (batch_size, 1024, num_points)
        x = self.maxpool(x)  # (batch_size, 1024, 1)
        x = x.view(batch_size, -1)  # (batch_size, 1024)

        # Apply the fully connected layers for classification
        x = F.relu(self.bn4(self.fc4(x)))  # (batch_size, 512)
        x = F.relu(self.bn5(self.fc5(x)))  # (batch_size, 256)
        x = self.fc6(x)  # (batch_size, num_classes)

        return x

# %%
num_classes = len(dataset.class_to_idx)

model = SimplePointNet(num_classes=num_classes)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

num_epochs = 10

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0

    for point_clouds, labels in train_loader:
        outputs = model(point_clouds)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss / len(train_loader)}')

    # Validation
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for point_clouds, labels in val_loader:
            outputs = model(point_clouds)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f'Validation Accuracy: {accuracy:.2f}%')
    
    torch.save(model.state_dict(), f'checkpoints/pointnet_epoch_{epoch+1}.pth')

torch.save(model.state_dict(), 'checkpoints/pointnet.pth')

# %%
test_model = SimplePointNet(num_classes=num_classes)  
test_model.load_state_dict(torch.load('checkpoints/pointnet.pth'))
test_model.eval()

correct = 0
total = 0
y_true = []
y_pred = []

with torch.no_grad():
    for point_clouds, labels in test_loader:
        outputs = model(point_clouds)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        y_true.extend(labels.numpy())
        y_pred.extend(predicted.numpy())
        
accuracy = 100 * correct / total
print(f'Test Accuracy: {accuracy:.2f}%')

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=dataset.idx_to_class.values(), yticklabels=dataset.idx_to_class.values())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
