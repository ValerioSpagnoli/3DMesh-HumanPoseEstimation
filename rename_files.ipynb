# %%
import os

# %%
# mesh_dataset_dir = f'datasets/human_seg/mesh_train'
# keypoint_dataset_dir = f'datasets/human_seg/keypoints_train'

# mesh_files = os.listdir(mesh_dataset_dir)
# mesh_files.sort() 
# keypoint_files = os.listdir(keypoint_dataset_dir)
# keypoint_files.sort()

# for i in range(len(mesh_files)):
#     mesh_file = mesh_files[i]
#     keypoint_file = keypoint_files[i]

#     mesh_name = f'mesh_{i:04d}.obj'
#     keypoint_name = f'keypoints_{i:04d}.csv'  
    
#     print(f'{mesh_file} -> {mesh_name}')
#     print(f'{keypoint_file} -> {keypoint_name}')
    
#     os.rename(f'{mesh_dataset_dir}/{mesh_file}', f'{mesh_dataset_dir}/{mesh_name}')
#     os.rename(f'{keypoint_dataset_dir}/{keypoint_file}', f'{keypoint_dataset_dir}/{keypoint_name}')

# %%
# mesh_dataset_dir = f'datasets/human_seg/mesh_test'

# mesh_files = os.listdir(mesh_dataset_dir)
# mesh_files.sort() 

# for i in range(len(mesh_files)):
#     mesh_file = mesh_files[i]

#     mesh_name = f'mesh_{i:04d}.obj'
    
#     print(f'{mesh_file} -> {mesh_name}')
    
#     os.rename(f'{mesh_dataset_dir}/{mesh_file}', f'{mesh_dataset_dir}/{mesh_name}')
# Out:
# mesh_0001.obj -> mesh_0000.obj
# mesh_0002.obj -> mesh_0001.obj
# mesh_0003.obj -> mesh_0002.obj
# mesh_0004.obj -> mesh_0003.obj
# mesh_0005.obj -> mesh_0004.obj
# mesh_0006.obj -> mesh_0005.obj
# mesh_0008.obj -> mesh_0006.obj
# mesh_0010.obj -> mesh_0007.obj
# mesh_0011.obj -> mesh_0008.obj
# mesh_0014.obj -> mesh_0009.obj
# mesh_0018.obj -> mesh_0010.obj
# mesh_0019.obj -> mesh_0011.obj
# mesh_0020.obj -> mesh_0012.obj
# mesh_0021.obj -> mesh_0013.obj
# mesh_0022.obj -> mesh_0014.obj
# mesh_0023.obj -> mesh_0015.obj
# mesh_0024.obj -> mesh_0016.obj
# mesh_0025.obj -> mesh_0017.obj
# mesh_0028.obj -> mesh_0018.obj
# mesh_0029.obj -> mesh_0019.obj
# mesh_0030.obj -> mesh_0020.obj
# mesh_0032.obj -> mesh_0021.obj
# mesh_0035.obj -> mesh_0022.obj
# mesh_0036.obj -> mesh_0023.obj
# mesh_0037.obj -> mesh_0024.obj
# mesh_0038.obj -> mesh_0025.obj
# mesh_0039.obj -> mesh_0026.obj
# mesh_0040.obj -> mesh_0027.obj
# mesh_0041.obj -> mesh_0028.obj
# mesh_0042.obj -> mesh_0029.obj
# mesh_0043.obj -> mesh_0030.obj
# mesh_0044.obj -> mesh_0031.obj
# mesh_0045.obj -> mesh_0032.obj
# mesh_0046.obj -> mesh_0033.obj
# mesh_0047.obj -> mesh_0034.obj
# mesh_0049.obj -> mesh_0035.obj
# mesh_0050.obj -> mesh_0036.obj
# mesh_0051.obj -> mesh_0037.obj
# mesh_0053.obj -> mesh_0038.obj
# mesh_0054.obj -> mesh_0039.obj
# mesh_0055.obj -> mesh_0040.obj
# mesh_0057.obj -> mesh_0041.obj
# mesh_0061.obj -> mesh_0042.obj
# mesh_0062.obj -> mesh_0043.obj
# mesh_0063.obj -> mesh_0044.obj
# mesh_0064.obj -> mesh_0045.obj
# mesh_0066.obj -> mesh_0046.obj
# mesh_0067.obj -> mesh_0047.obj
# mesh_0070.obj -> mesh_0048.obj
# mesh_0071.obj -> mesh_0049.obj
# mesh_0072.obj -> mesh_0050.obj
# mesh_0073.obj -> mesh_0051.obj
# mesh_0074.obj -> mesh_0052.obj
# mesh_0075.obj -> mesh_0053.obj
# mesh_0078.obj -> mesh_0054.obj
# mesh_0079.obj -> mesh_0055.obj
# mesh_0080.obj -> mesh_0056.obj
# mesh_0081.obj -> mesh_0057.obj
# mesh_0082.obj -> mesh_0058.obj
# mesh_0083.obj -> mesh_0059.obj
# mesh_0084.obj -> mesh_0060.obj
# mesh_0086.obj -> mesh_0061.obj
# mesh_0087.obj -> mesh_0062.obj
# mesh_0089.obj -> mesh_0063.obj
# mesh_0090.obj -> mesh_0064.obj
# mesh_0093.obj -> mesh_0065.obj
# mesh_0095.obj -> mesh_0066.obj
# mesh_0096.obj -> mesh_0067.obj
# mesh_0097.obj -> mesh_0068.obj
# mesh_0101.obj -> mesh_0069.obj
# mesh_0102.obj -> mesh_0070.obj
# mesh_0103.obj -> mesh_0071.obj
# mesh_0104.obj -> mesh_0072.obj
# mesh_0105.obj -> mesh_0073.obj
# mesh_0107.obj -> mesh_0074.obj
# mesh_0108.obj -> mesh_0075.obj
# mesh_0109.obj -> mesh_0076.obj
# mesh_0110.obj -> mesh_0077.obj
# mesh_0111.obj -> mesh_0078.obj
# mesh_0112.obj -> mesh_0079.obj
# mesh_0115.obj -> mesh_0080.obj
# mesh_0117.obj -> mesh_0081.obj
# mesh_0118.obj -> mesh_0082.obj
# mesh_0120.obj -> mesh_0083.obj
# mesh_0121.obj -> mesh_0084.obj
# mesh_0122.obj -> mesh_0085.obj
# mesh_0123.obj -> mesh_0086.obj
# mesh_0124.obj -> mesh_0087.obj
# mesh_0125.obj -> mesh_0088.obj
# mesh_0128.obj -> mesh_0089.obj
# mesh_0129.obj -> mesh_0090.obj
# mesh_0130.obj -> mesh_0091.obj
# mesh_0133.obj -> mesh_0092.obj
# mesh_0135.obj -> mesh_0093.obj
# mesh_0136.obj -> mesh_0094.obj
# mesh_0137.obj -> mesh_0095.obj
# mesh_0138.obj -> mesh_0096.obj
# mesh_0139.obj -> mesh_0097.obj
# mesh_0140.obj -> mesh_0098.obj
# mesh_0142.obj -> mesh_0099.obj
# mesh_0143.obj -> mesh_0100.obj
# mesh_0144.obj -> mesh_0101.obj
# mesh_0145.obj -> mesh_0102.obj
# mesh_0146.obj -> mesh_0103.obj
# mesh_0147.obj -> mesh_0104.obj
# mesh_0148.obj -> mesh_0105.obj
# mesh_0149.obj -> mesh_0106.obj
# mesh_0150.obj -> mesh_0107.obj
# mesh_0153.obj -> mesh_0108.obj
# mesh_0154.obj -> mesh_0109.obj
# mesh_0155.obj -> mesh_0110.obj
# mesh_0156.obj -> mesh_0111.obj
# mesh_0157.obj -> mesh_0112.obj
# mesh_0159.obj -> mesh_0113.obj
# mesh_0160.obj -> mesh_0114.obj
# mesh_0161.obj -> mesh_0115.obj
# mesh_0162.obj -> mesh_0116.obj
# mesh_0163.obj -> mesh_0117.obj
# mesh_0164.obj -> mesh_0118.obj
# mesh_0165.obj -> mesh_0119.obj
# mesh_0166.obj -> mesh_0120.obj
# mesh_0168.obj -> mesh_0121.obj
# mesh_0169.obj -> mesh_0122.obj
# mesh_0170.obj -> mesh_0123.obj
# mesh_0171.obj -> mesh_0124.obj
# mesh_0172.obj -> mesh_0125.obj
# mesh_0173.obj -> mesh_0126.obj
# mesh_0174.obj -> mesh_0127.obj
# mesh_0175.obj -> mesh_0128.obj
# mesh_0176.obj -> mesh_0129.obj
# mesh_0177.obj -> mesh_0130.obj
# mesh_0178.obj -> mesh_0131.obj
# mesh_0179.obj -> mesh_0132.obj
# mesh_0180.obj -> mesh_0133.obj
# mesh_0181.obj -> mesh_0134.obj
# mesh_0182.obj -> mesh_0135.obj
# mesh_0183.obj -> mesh_0136.obj
# mesh_0184.obj -> mesh_0137.obj
# mesh_0185.obj -> mesh_0138.obj
# mesh_0186.obj -> mesh_0139.obj
# mesh_0187.obj -> mesh_0140.obj
# mesh_0188.obj -> mesh_0141.obj
# mesh_0189.obj -> mesh_0142.obj
# mesh_0190.obj -> mesh_0143.obj
# mesh_0191.obj -> mesh_0144.obj
# mesh_0192.obj -> mesh_0145.obj
# mesh_0193.obj -> mesh_0146.obj
# mesh_0194.obj -> mesh_0147.obj
# mesh_0195.obj -> mesh_0148.obj
# mesh_0197.obj -> mesh_0149.obj
# mesh_0198.obj -> mesh_0150.obj
# mesh_0199.obj -> mesh_0151.obj
# mesh_0200.obj -> mesh_0152.obj
# mesh_0201.obj -> mesh_0153.obj
# mesh_0202.obj -> mesh_0154.obj
# mesh_0203.obj -> mesh_0155.obj
# mesh_0204.obj -> mesh_0156.obj
# mesh_0205.obj -> mesh_0157.obj
# mesh_0206.obj -> mesh_0158.obj
# mesh_0207.obj -> mesh_0159.obj
# mesh_0208.obj -> mesh_0160.obj
# mesh_0209.obj -> mesh_0161.obj
# mesh_0210.obj -> mesh_0162.obj
# mesh_0212.obj -> mesh_0163.obj
# mesh_0215.obj -> mesh_0164.obj
# mesh_0217.obj -> mesh_0165.obj
# mesh_0219.obj -> mesh_0166.obj
# mesh_0220.obj -> mesh_0167.obj
# mesh_0223.obj -> mesh_0168.obj
# mesh_0226.obj -> mesh_0169.obj
# mesh_0227.obj -> mesh_0170.obj
# mesh_0228.obj -> mesh_0171.obj
# mesh_0231.obj -> mesh_0172.obj
# mesh_0233.obj -> mesh_0173.obj
# mesh_0234.obj -> mesh_0174.obj
# mesh_0239.obj -> mesh_0175.obj
# mesh_0242.obj -> mesh_0176.obj
# mesh_0244.obj -> mesh_0177.obj
# mesh_0245.obj -> mesh_0178.obj
# mesh_0249.obj -> mesh_0179.obj
# mesh_0252.obj -> mesh_0180.obj
# mesh_0254.obj -> mesh_0181.obj
# mesh_0255.obj -> mesh_0182.obj
# mesh_0256.obj -> mesh_0183.obj
# mesh_0257.obj -> mesh_0184.obj
# mesh_0258.obj -> mesh_0185.obj
# mesh_0260.obj -> mesh_0186.obj
# mesh_0265.obj -> mesh_0187.obj
# mesh_0266.obj -> mesh_0188.obj
# mesh_0267.obj -> mesh_0189.obj
# mesh_0268.obj -> mesh_0190.obj
# mesh_0273.obj -> mesh_0191.obj
# mesh_0274.obj -> mesh_0192.obj
# mesh_0285.obj -> mesh_0193.obj
# mesh_0286.obj -> mesh_0194.obj
# mesh_0287.obj -> mesh_0195.obj
# mesh_0288.obj -> mesh_0196.obj
# mesh_0289.obj -> mesh_0197.obj
# mesh_0290.obj -> mesh_0198.obj
# mesh_0294.obj -> mesh_0199.obj
# mesh_0295.obj -> mesh_0200.obj
# mesh_0297.obj -> mesh_0201.obj
# mesh_0298.obj -> mesh_0202.obj
# mesh_0300.obj -> mesh_0203.obj
# mesh_0301.obj -> mesh_0204.obj
# mesh_0302.obj -> mesh_0205.obj
# mesh_0307.obj -> mesh_0206.obj
# mesh_0308.obj -> mesh_0207.obj
# mesh_0309.obj -> mesh_0208.obj
# mesh_0312.obj -> mesh_0209.obj
# mesh_0314.obj -> mesh_0210.obj
# mesh_0316.obj -> mesh_0211.obj
# mesh_0317.obj -> mesh_0212.obj
# mesh_0318.obj -> mesh_0213.obj
# mesh_0322.obj -> mesh_0214.obj
# mesh_0325.obj -> mesh_0215.obj
# mesh_0330.obj -> mesh_0216.obj
# mesh_0333.obj -> mesh_0217.obj
# mesh_0334.obj -> mesh_0218.obj
# mesh_0337.obj -> mesh_0219.obj
# mesh_0338.obj -> mesh_0220.obj
# mesh_0341.obj -> mesh_0221.obj
# mesh_0351.obj -> mesh_0222.obj
# mesh_0353.obj -> mesh_0223.obj
# mesh_0354.obj -> mesh_0224.obj
# mesh_0357.obj -> mesh_0225.obj
# mesh_0358.obj -> mesh_0226.obj
# mesh_0359.obj -> mesh_0227.obj
# mesh_0360.obj -> mesh_0228.obj
# mesh_0361.obj -> mesh_0229.obj
# mesh_0363.obj -> mesh_0230.obj
# mesh_0365.obj -> mesh_0231.obj
# mesh_0366.obj -> mesh_0232.obj
# mesh_0367.obj -> mesh_0233.obj
# mesh_0368.obj -> mesh_0234.obj
# mesh_0371.obj -> mesh_0235.obj
# mesh_0375.obj -> mesh_0236.obj
# mesh_0377.obj -> mesh_0237.obj
# mesh_0379.obj -> mesh_0238.obj
# mesh_0380.obj -> mesh_0239.obj
# shrec__1.obj -> mesh_0240.obj
# shrec__10.obj -> mesh_0241.obj
# shrec__11.obj -> mesh_0242.obj
# shrec__12.obj -> mesh_0243.obj
# shrec__13.obj -> mesh_0244.obj
# shrec__14.obj -> mesh_0245.obj
# shrec__15.obj -> mesh_0246.obj
# shrec__17.obj -> mesh_0247.obj
# shrec__19.obj -> mesh_0248.obj
# shrec__2.obj -> mesh_0249.obj
# shrec__20.obj -> mesh_0250.obj
# shrec__3.obj -> mesh_0251.obj
# shrec__4.obj -> mesh_0252.obj
# shrec__5.obj -> mesh_0253.obj
# shrec__6.obj -> mesh_0254.obj
# shrec__7.obj -> mesh_0255.obj
# shrec__8.obj -> mesh_0256.obj
# shrec__9.obj -> mesh_0257.obj
