# %%
import os

# %%
# mesh_dataset_dir = f'datasets/mesh_keypoints_extraction/mesh'
# keypoint_dataset_dir = f'datasets/mesh_keypoints_extraction/keypoint'

# mesh_files = os.listdir(mesh_dataset_dir)
# mesh_files.sort() 
# keypoint_files = os.listdir(keypoint_dataset_dir)
# keypoint_files.sort()

# for i in range(len(mesh_files)):
#     mesh_file = mesh_files[i]
#     keypoint_file = keypoint_files[i]

#     mesh_name = f'mesh_{i:04d}.obj'
#     keypoint_name = f'keypoints_{i:04d}.csv'  
    
#     print(f'{mesh_file} -> {mesh_name}')
#     print(f'{keypoint_file} -> {keypoint_name}')
    
#     os.rename(f'{mesh_dataset_dir}/{mesh_file}', f'{mesh_dataset_dir}/{mesh_name}')
#     os.rename(f'{keypoint_dataset_dir}/{keypoint_file}', f'{keypoint_dataset_dir}/{keypoint_name}')
# Out:
# mesh_0000.obj -> mesh_0000.obj
# mesh_0000.csv -> keypoints_0000.csv
# mesh_0001.obj -> mesh_0001.obj
# mesh_0001.csv -> keypoints_0001.csv
# mesh_0003.obj -> mesh_0002.obj
# mesh_0003.csv -> keypoints_0002.csv
# mesh_0006.obj -> mesh_0003.obj
# mesh_0006.csv -> keypoints_0003.csv
# mesh_0007.obj -> mesh_0004.obj
# mesh_0007.csv -> keypoints_0004.csv
# mesh_0008.obj -> mesh_0005.obj
# mesh_0008.csv -> keypoints_0005.csv
# mesh_0009.obj -> mesh_0006.obj
# mesh_0009.csv -> keypoints_0006.csv
# mesh_0011.obj -> mesh_0007.obj
# mesh_0011.csv -> keypoints_0007.csv
# mesh_0012.obj -> mesh_0008.obj
# mesh_0012.csv -> keypoints_0008.csv
# mesh_0013.obj -> mesh_0009.obj
# mesh_0013.csv -> keypoints_0009.csv
# mesh_0014.obj -> mesh_0010.obj
# mesh_0014.csv -> keypoints_0010.csv
# mesh_0015.obj -> mesh_0011.obj
# mesh_0015.csv -> keypoints_0011.csv
# mesh_0016.obj -> mesh_0012.obj
# mesh_0016.csv -> keypoints_0012.csv
# mesh_0017.obj -> mesh_0013.obj
# mesh_0017.csv -> keypoints_0013.csv
# ...

# %%
# mesh_dataset_dir = f'datasets/mesh_keypoints_extraction/other_mesh'

# mesh_files = os.listdir(mesh_dataset_dir)
# mesh_files.sort() 

# for i in range(len(mesh_files)):
#     mesh_file = mesh_files[i]

#     mesh_name = f'mesh_{i:04d}.obj'
    
#     print(f'{mesh_file} -> {mesh_name}')
    
#     os.rename(f'{mesh_dataset_dir}/{mesh_file}', f'{mesh_dataset_dir}/{mesh_name}')
# Out:
# mesh_0002.obj -> mesh_0000.obj
# mesh_0004.obj -> mesh_0001.obj
# mesh_0005.obj -> mesh_0002.obj
# mesh_0010.obj -> mesh_0003.obj
# mesh_0018.obj -> mesh_0004.obj
# mesh_0019.obj -> mesh_0005.obj
# mesh_0020.obj -> mesh_0006.obj
# mesh_0021.obj -> mesh_0007.obj
# mesh_0022.obj -> mesh_0008.obj
# mesh_0024.obj -> mesh_0009.obj
# mesh_0028.obj -> mesh_0010.obj
# mesh_0030.obj -> mesh_0011.obj
# mesh_0032.obj -> mesh_0012.obj
# mesh_0035.obj -> mesh_0013.obj
# mesh_0036.obj -> mesh_0014.obj
# mesh_0037.obj -> mesh_0015.obj
# mesh_0038.obj -> mesh_0016.obj
# mesh_0039.obj -> mesh_0017.obj
# mesh_0040.obj -> mesh_0018.obj
# mesh_0042.obj -> mesh_0019.obj
# mesh_0043.obj -> mesh_0020.obj
# mesh_0044.obj -> mesh_0021.obj
# mesh_0045.obj -> mesh_0022.obj
# mesh_0047.obj -> mesh_0023.obj
# mesh_0049.obj -> mesh_0024.obj
# mesh_0050.obj -> mesh_0025.obj
# mesh_0051.obj -> mesh_0026.obj
# mesh_0053.obj -> mesh_0027.obj
# mesh_0083.obj -> mesh_0028.obj
# mesh_0090.obj -> mesh_0029.obj
# ...
